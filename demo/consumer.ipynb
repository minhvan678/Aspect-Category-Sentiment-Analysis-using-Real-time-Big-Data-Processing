# %%
from kafka import KafkaConsumer
from pymongo import MongoClient
from json import loads

# %%
topic_name = 'traveloka'
kafka_server = 'localhost:9092'

# %%
consumer = KafkaConsumer(
    topic_name,
    bootstrap_servers=kafka_server,
    auto_offset_reset = 'latest',
    enable_auto_commit = True,
    group_id = 'my-group', 
    value_deserializer = lambda x: loads(x)
)

# %%
client = MongoClient("mongodb+srv://nhq188:fiora123@cluster0.vcb5k8u.mongodb.net/")
collection = client.traveloka.comment

# %%
import time

for message in consumer:
    try:
        mess = loads(message.value)
        if mess['comment'] == None:
            mess['comment'] = ""
        collection.insert_one(mess)
        print(f"{mess} added to {collection}")
        time.sleep(1)
    except:
        mess = message.value
        if mess['comment'] == None:
            mess['comment'] = ""
        collection.insert_one(mess)
        print(f"{mess} added to {collection}")
        time.sleep(1)
    else:
        pass
# Out:
# {'comment': 'Vô cùng hài lòng, nhân viên thân thiện chu đáo. ăn sáng ok luôn. View thì khỏi phải bàn.', 'hotel_id': 'Seashore Hotel & Apartment', 'timestamp': 'Thu Jan 25 07:52:12 2024', '_id': ObjectId('65ba67dd32d8db9727a9ba83')} added to Collection(Database(MongoClient(host=['ac-smv28uo-shard-00-02.vcb5k8u.mongodb.net:27017', 'ac-smv28uo-shard-00-00.vcb5k8u.mongodb.net:27017', 'ac-smv28uo-shard-00-01.vcb5k8u.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-68861v-shard-0', tls=True), 'traveloka'), 'comment')
# ...

# %%
# import time

# for message in consumer:
#     mess = message.value
#     print(mess)
#     if mess['comment'] == None:
#         mess['comment'] = ""
#     collection.insert_one(mess)
#     print(f"{mess} added to {collection}")
#     time.sleep(2)
# Out:
# {'comment': 'Mình lựa chọn khách sạn vì có hồ bơi đẹp. Cây xanh nhiều. Hoa đẹp. Tuy nhiên phòng ghim đang sửa chữa. View biển đẹp. Buổi tối nhìn qua khách sạn Mường Thanh có đèn led rất đẹp Khách sạn gần biển. Đi vòng qua mấy khách sạn là tới', 'hotel_id': 'Volga Hotel Nha Trang'}
# {'comment': 'Mình lựa chọn khách sạn vì có hồ bơi đẹp. Cây xanh nhiều. Hoa đẹp. Tuy nhiên phòng ghim đang sửa chữa. View biển đẹp. Buổi tối nhìn qua khách sạn Mường Thanh có đèn led rất đẹp Khách sạn gần biển. Đi vòng qua mấy khách sạn là tới', 'hotel_id': 'Volga Hotel Nha Trang', '_id': ObjectId('65abf60c62e2bb63ee786c63')} added to Collection(Database(MongoClient(host=['ac-smv28uo-shard-00-02.vcb5k8u.mongodb.net:27017', 'ac-smv28uo-shard-00-00.vcb5k8u.mongodb.net:27017', 'ac-smv28uo-shard-00-01.vcb5k8u.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-68861v-shard-0', tls=True), 'traveloka'), 'comment')
# ...
